# %%
import folium
import pandas as pd
from folium.plugins import HeatMap

# %%
df=pd.read_csv("../data/processed/clean_airbnb.gz")

# %%
#df1=pd.read_csv("../data/processed/clean_listings.gz")

# %%
# Keep only rows where "state" is "North Carolina"
# 3003 listings
df_nc = df1[df1['state'] == 'North Carolina']

# %%
# Keep only unique rows based on the "id" column
#1833 listings
df_unique = df.drop_duplicates(subset=['id'])
df_unique.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1833 entries, 0 to 668680
# Data columns (total 28 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            1833 non-null   int64
#  1   name                                          1833 non-null   object
#  2   price                                         1833 non-null   float64
#  3   date                                          1833 non-null   object
#  4   available                                     1833 non-null   object
#  5   room_type                                     1833 non-null   object
#  6   accommodates                                  1833 non-null   int64
#  7   bedrooms                                      1833 non-null   float64
#  8   beds                                          1833 non-null   float64
#  9   amenities                                     1833 non-null   object
#  10  latitude                                      1833 non-null   float64
#  11  longitude                                     1833 non-null   float64
#  12  property_type                                 1833 non-null   object
#  13  host_id                                       1833 non-null   int64
#  14  host_since                                    1833 non-null   object
#  15  host_location                                 1638 non-null   object
#  16  host_response_time                            1589 non-null   object
#  17  host_response_rate                            1589 non-null   object
#  18  host_acceptance_rate                          1728 non-null   object
#  19  minimum_nights                                1833 non-null   int64
#  20  maximum_nights                                1833 non-null   int64
#  21  number_of_reviews                             1833 non-null   int64
#  22  review_scores_rating                          1833 non-null   float64
#  23  reviews_per_month                             1833 non-null   float64
#  24  calculated_host_listings_count                1833 non-null   int64
#  25  calculated_host_listings_count_entire_homes   1833 non-null   int64
#  26  calculated_host_listings_count_private_rooms  1833 non-null   int64
#  27  calculated_host_listings_count_shared_rooms   1833 non-null   int64
# dtypes: float64(7), int64(10), object(11)
# memory usage: 415.3+ KB

# %%
df_unique.to_csv("../data/processed/clean_airbnb_unique.csv", index=False)

# %%
df.head()
# Out:
#        id                                               name  host_id  \
# 0  108061  Walk to stores/parks/downtown. Fenced yard/Pet...   320564
# 1  155305                 Cottage! BonPaul + Sharky's Hostel   746673
# 2  156805                  Private Room "Ader" at BPS Hostel   746673
# 3  197263                       Tranquil Room & Private Bath   961396
# 4  209068                                    Terrace Cottage  1029919
#
#    host_since  host_response_time host_response_rate host_acceptance_rate  \
# 0  2010-12-16      within an hour               100%                  71%
# 1  2011-06-26      within an hour               100%                  99%
# 2  2011-06-26      within an hour               100%                  99%
# 3  2011-08-12  within a few hours               100%                  93%
# 4  2011-08-28  within a few hours               100%                  44%
#
#    host_total_listings_count  latitude  longitude  ... availability_365  \
# 0                        3.0  35.60670  -82.55563  ...              246
# 1                       11.0  35.57864  -82.59578  ...              197
# 2                       11.0  35.57864  -82.59578  ...                0
# 3                        2.0  35.57808  -82.63689  ...               88
# 4                        1.0  35.61856  -82.55276  ...              231
#
#   number_of_reviews  review_scores_rating  review_scores_accuracy  \
# 0                92                  4.51                    4.56
# 1               383                  4.59                    4.72
# 2                67                  4.52                    4.73
# 3                66                  4.95                    4.97
# 4                60                  4.87                    4.84
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.70                   4.85
# 1                       4.42                   4.83
# 2                       4.43                   4.76
# 3                       5.00                   4.95
# 4                       4.84                   5.00
#
#    review_scores_communication  review_scores_location       city  \
# 0                         4.80                    4.84  Asheville
# 1                         4.74                    4.93  Asheville
# 2                         4.61                    4.84  Asheville
# 3                         4.92                    4.82  Asheville
# 4                         4.98                    4.93  Asheville
#
#             state
# 0  North Carolina
# 1  North Carolina
# 2  North Carolina
# 3  North Carolina
# 4  North Carolina
#
# [5 rows x 31 columns]

# %%
default_location = [35.585601, -82.544137]
default_zoom_start = 10

base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c165be6cb3f9d938d2eb38ccbcb6d1ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c165be6cb3f9d938d2eb38ccbcb6d1ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c165be6cb3f9d938d2eb38ccbcb6d1ab = L.map(
#                 &quot;map_c165be6cb3f9d938d2eb38ccbcb6d1ab&quot;,
#                 {
#                     center: [35.585601, -82.544137],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c165be6cb3f9d938d2eb38ccbcb6d1ab);
#
#
#
#
#
#             var tile_layer_1644676ccfa4ff7b32ccc60026b8e90a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c165be6cb3f9d938d2eb38ccbcb6d1ab);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_location_counts = df_unique.value_counts(['latitude', 'longitude']).reset_index(name='counts')
df_location_counts.head()
# Out:
#     latitude  longitude  counts
# 0  35.595460 -82.554210       8
# 1  35.594006 -82.553131       8
# 2  35.595240 -82.552190       8
# 3  35.607040 -82.564530       7
# 4  35.605280 -82.569700       4

# %%
base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
HeatMap(data=df_location_counts.values.tolist(), radius=8, max_zoom=13).add_to(base_map)
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04a35cfcec11e1967693292e7b23f827 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04a35cfcec11e1967693292e7b23f827&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04a35cfcec11e1967693292e7b23f827 = L.map(
#                 &quot;map_04a35cfcec11e1967693292e7b23f827&quot;,
#                 {
#                     center: [35.585601, -82.544137],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_04a35cfcec11e1967693292e7b23f827);
#
#
#
#
#
#             var tile_layer_318e5ad6f83c9366c97216e49ea528d7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_04a35cfcec11e1967693292e7b23f827);
#
#
#             var heat_map_7f1682c9b937a1f4425e15bd0aef5c1d = L.heatLayer(
#                 [[35.59546, -82.55421, 8.0], [35.594006, -82.553131, 8.0], [35.59524, -82.55219, 8.0], [35.60704, -82.56453, 7.0], [35.60528, -82.5697, 4.0], [35.597107, -82.552101, 4.0], [35.57481, -82.55725, 4.0], [35.59751, -82.55339, 4.0], [35.59731, -82.55268, 3.0], [35.59848, -82.55506, 3.0], [35.57864, -82.59578, 2.0], [35.59442, -82.55396, 2.0], [35.60355, -82.55703, 2.0], [35.586372, -82.578987, 2.0], [35.599442, -82.558548, 2.0], [35.59602, -82.55061, 2.0], [35.47041, -82.50005, 2.0], [35.57895, -82.59566, 2.0], [35.59841, -82.46546, 1.0], [35.59834, -82.50299, 1.0], [35.59822, -82.55504, 1.0], [35.5984, -82.55659, 1.0], [35.59841, -82.56367, 1.0], [35.59841, -82.60181, 1.0], [35.42342, -82.47322, 1.0], [35.598209, -82.560051, 1.0], [35.5982, -82.55433, 1.0], [35.5981, -82.55443, 1.0], [35.5981, -82.56631, 1.0], [35.59808, -82.55833, 1.0], [35.59804, -82.55587, 1.0], [35.59795, -82.61103, 1.0], [35.597935, -82.553123, 1.0], [35.59791, -82.55826, 1.0], [35.59784, -82.48396, 1.0], [35.5978, -82.56623, 1.0], [35.59846, -82.48267, 1.0], [35.59863, -82.60372, 1.0], [35.59852, -82.51166, 1.0], [35.59937, -82.48604, 1.0], [35.60002, -82.50277, 1.0], [35.60001, -82.50032, 1.0], [35.59997, -82.56133